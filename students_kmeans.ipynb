# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('student_kmeans_dataset.csv')

# %%
df.head()
# Out:
#    cgpa  iq
# 0  6.70  93
# 1  6.44  94
# 2  6.76  99
# 3  7.11  98
# 4  6.41  79

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    km.inertia_
    wcss.append(km.inertia_)

# %%
print(wcss)
# Out:
# [65066.64474999999, 17451.90991674718, 8029.291661549784, 4621.532201071908, 2956.2538430279346, 2324.2287267639285, 1778.3669378634906, 1294.4273312605785, 1120.944011438786, 876.0065270637706]

# %%
plt.plot(range(1,11),wcss)

# %%
X=df.iloc[:,:].values
km=KMeans(n_clusters=4)
y_means=km.fit_predict(X)

# %%
X[y_means==3,1]
# Out:
# array([128., 128., 133., 137., 142., 139., 134., 135., 130., 135., 134.,
#        137., 131., 138., 143., 134., 137., 138., 133., 136., 135., 135.,
#        131., 135., 137., 142., 140., 146., 131., 139., 136., 146., 131.,
#        131., 132., 132., 131., 136., 137., 144., 140., 132., 131., 137.,
#        128., 144., 141., 133., 142., 134., 141.])

# %%
X[y_means==3,0]
# Out:
# array([9.07, 8.44, 8.08, 9.25, 9.27, 9.06, 9.25, 9.26, 9.06, 9.57, 9.29,
#        8.96, 9.33, 9.01, 9.36, 9.43, 9.04, 9.39, 9.28, 9.36, 9.58, 9.15,
#        9.05, 9.02, 9.04, 9.18, 9.27, 9.26, 9.37, 9.2 , 9.49, 9.15, 9.74,
#        9.33, 9.03, 9.3 , 9.16, 9.34, 9.29, 9.19, 9.03, 8.9 , 9.11, 9.37,
#        9.24, 8.95, 9.23, 9.28, 9.23, 9.21, 8.97])

# %%
plt.scatter(X[y_means==0,0],X[y_means==0,1],color='blue')
plt.scatter(X[y_means==1,0],X[y_means==1,1],color='red')
plt.scatter(X[y_means==2,0],X[y_means==2,1],color='green')
plt.scatter(X[y_means==3,0],X[y_means==3,1],color='yellow')
